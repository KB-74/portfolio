# %% [markdown]
# # Picture processing
#
# by: <br/>
# Jelte Molenaar <br/>
# Michiel van Soest
#
# In deze notebook worden de huidige afbeeldingen aangepast en opgeslagen om meer data te creëren voor het RCNN.

# %%
from PIL import Image
from PIL import ImageEnhance
import glob

# %%
# folder path voor de output
folder_path = "/datc/shipping/processed_pictures_m/frames/"

# %% [markdown]
# ## Aanpassingen op de originele frame

# %%
brightness_factor = [0.3,1.4]        # [0.4,0.5,0.6,0.7,0.8,0.9,1.1,1.2,1.3,1.4]
contrast_factor   = [0.3,1.4]        # [0.4,0.5,0.6,0.7,0.8,0.9,1.0,1.2,1.3,1.4]
sharpness_factor  = [5.0,20.0]        # [5.0, 10.0, 15.0, 20.0]
color_factor      = [0.0,10.0]             # [0.0, 3.0, 6.0, 10.0]
mirror_factor     = [1]

# %% [markdown]
# ## Functies

# %%
def adjust_brightness(img_origional, frame_number, brightness_factor):
    frame_savename = folder_path + 'frame_' + str(frame_number) +'.jpg'
    enhancer_object = ImageEnhance.Brightness(img_origional)
    out = enhancer_object.enhance(brightness_factor)
    out.save(frame_savename)

# %%
def adjust_contrast(img_origional, frame_number, contrast_factor):
    frame_savename = folder_path + 'frame_' + str(frame_number) +'.jpg'
    enhancer_object = ImageEnhance.Contrast(img_origional)
    out = enhancer_object.enhance(contrast_factor)
    out.save(frame_savename)

# %%
def adjust_sharpness(img_origional, frame_number, sharpness_factor):
    frame_savename = folder_path + 'frame_' + str(frame_number) +'.jpg'
    enhancer_object = ImageEnhance.Sharpness(img_origional)
    out = enhancer_object.enhance(sharpness_factor)
    out.save(frame_savename)

# %%
def adjust_color(img_origional, frame_number, color_factor):
    frame_savename =  folder_path + 'frame_' + str(frame_number) +'.jpg'
    enhancer_object = ImageEnhance.Color(img_origional)
    out = enhancer_object.enhance(color_factor)
    out.save(frame_savename)

# %%
def copy_overlay(overlay_origional, frame_number, overlay_number):
    overlay_savename = "/datc/shipping/processed_pictures_m/overlays/frame_"+ str(frame_number) +'_mask.gif'
    overlay_origional.save(overlay_savename)

# %%
def mirror_image_origional(img_origional, frame_number, mirror_factor):
    frame_savename =  folder_path + 'frame_' + str(frame_number) +'.jpg'
    out = img_origional.transpose(Image.FLIP_LEFT_RIGHT)
    out.save(frame_savename)

# %%
def mirror_image_overlay(overlay_origional, frame_number, overlay_number):
    overlay_savename = "/datc/shipping/processed_pictures_m/overlays/frame_"+ str(frame_number) +'_mask.gif'
    out = overlay_origional.transpose(Image.FLIP_LEFT_RIGHT)
    out.save(overlay_savename)

# %% [markdown]
# ### Loop - functie

# %%
def changeimage(location_frames,brightness_factor,contrast_factor,sharpness_factor,color_factor, frame_number, location_overlays):
    img_origional = Image.open(location_frames)
    overlay_origional = Image.open(location_overlays)
    for x in brightness_factor:
        frame_number = frame_number + 1
        adjust_brightness(img_origional, frame_number, x)
        print(frame_number, "brightness", x)
        copy_overlay(overlay_origional, frame_number, overlay_number)

    for x in contrast_factor:
        frame_number = frame_number + 1
        adjust_contrast(img_origional, frame_number, x)
        print(frame_number, "contrast" , x)
        copy_overlay(overlay_origional, frame_number, overlay_number)

    for x in sharpness_factor:
        frame_number = frame_number + 1
        adjust_sharpness(img_origional, frame_number, x)
        print(frame_number, "sharpness", x)
        copy_overlay(overlay_origional, frame_number, overlay_number)

    for x in color_factor:
        frame_number = frame_number + 1
        adjust_color(img_origional, frame_number, x)
        print(frame_number, "Color", x)
        copy_overlay(overlay_origional, frame_number, overlay_number)
    
    for x in mirror_factor:
        frame_number = frame_number + 1
        mirror_image_origional(img_origional, frame_number, x)
        print(frame_number, "mirror origional")
        mirror_image_overlay(overlay_origional, frame_number, overlay_number)
        
    return frame_number

# %% [markdown]
# ## opschonen output directory

# %%
#clean directory

import glob, os, os.path

mydir = '/datc/shipping/processed_pictures_m/frames/'

filelist = glob.glob(os.path.join(mydir, "*.jpg"))
for f in filelist:
    os.remove(f)
    
mydir = '/datc/shipping/processed_pictures_m/overlays/'

filelist = glob.glob(os.path.join(mydir, "*.gif"))
for f in filelist:
    os.remove(f)

# %% [markdown]
# ## aanmaken frames en overlays met aanpassingen

# %%
#"test weghalen als het geen test meer is"
frame_number = 250
overlay_number = 9999

frames_number = glob.glob("/datc/shipping/origional_pictures_m/frames/*")
frames_number = len(frames_number)
print(frames_number, "frames in directory"  )
frames =  len(brightness_factor) + len(sharpness_factor) + len(color_factor) + len(contrast_factor) + len(mirror_factor) #aantal bewerkingen
print(frames, "adjustments on frames"  )

frame = "/datc/shipping/origional_pictures_m/frames/frame_1.jpg" #origional image
overlay = '/datc/shipping/origional_pictures_m/overlays/frame_1_mask.gif' #origional overlay

for i in range(frames_number):
    print("___________________","bewerken afbeelding",i + 1,"___________________")
    changeimage(frame,brightness_factor,contrast_factor,sharpness_factor,color_factor, frame_number, overlay)
    frame_number = frame_number + frames
    
    frame = '/datc/shipping/origional_pictures_m/frames/frame_'+str(i + 1)+'.jpg' #origional image
    overlay = '/datc/shipping/origional_pictures_m/overlays/frame_'+str(i + 1)+'_mask.gif' #origional overlay
# Out:
# 250 frames in directory
# 9 adjustments on frames
# ___________________ bewerken afbeelding 1 ___________________
# 251 brightness 0.3
# 252 brightness 1.4
# 253 contrast 0.3
# 254 contrast 1.4
# 255 sharpness 5.0
# 256 sharpness 20.0
# 257 Color 0.0
# 258 Color 10.0
# 259 mirror origional
# ___________________ bewerken afbeelding 2 ___________________
# 260 brightness 0.3
# 261 brightness 1.4
# 262 contrast 0.3
# 263 contrast 1.4
# 264 sharpness 5.0
# 265 sharpness 20.0
# 266 Color 0.0
# 267 Color 10.0
# 268 mirror origional
# ___________________ bewerken afbeelding 3 ___________________
# 269 brightness 0.3
# 270 brightness 1.4
# 271 contrast 0.3
# 272 contrast 1.4
# 273 sharpness 5.0
# 274 sharpness 20.0
# 275 Color 0.0
# 276 Color 10.0
# 277 mirror origional
# ___________________ bewerken afbeelding 4 ___________________
# 278 brightness 0.3
# 279 brightness 1.4
# 280 contrast 0.3
# 281 contrast 1.4
# 282 sharpness 5.0
# 283 sharpness 20.0
# 284 Color 0.0
# 285 Color 10.0
# 286 mirror origional
# ___________________ bewerken afbeelding 5 ___________________
# 287 brightness 0.3
# 288 brightness 1.4
# 289 contrast 0.3
# 290 contrast 1.4
# 291 sharpness 5.0
# 292 sharpness 20.0
# 293 Color 0.0
# 294 Color 10.0
# 295 mirror origional
# ___________________ bewerken afbeelding 6 ___________________
# 296 brightness 0.3
# 297 brightness 1.4
# 298 contrast 0.3
# 299 contrast 1.4
# 300 sharpness 5.0
# 301 sharpness 20.0
# 302 Color 0.0
# 303 Color 10.0
# 304 mirror origional
# ___________________ bewerken afbeelding 7 ___________________
# 305 brightness 0.3
# 306 brightness 1.4
# 307 contrast 0.3
# 308 contrast 1.4
# 309 sharpness 5.0
# 310 sharpness 20.0
# 311 Color 0.0
# 312 Color 10.0
# 313 mirror origional
# ___________________ bewerken afbeelding 8 ___________________
# 314 brightness 0.3
# 315 brightness 1.4
# 316 contrast 0.3
# 317 contrast 1.4
# 318 sharpness 5.0
# 319 sharpness 20.0
# 320 Color 0.0
# 321 Color 10.0
# 322 mirror origional
# ___________________ bewerken afbeelding 9 ___________________
# 323 brightness 0.3
# 324 brightness 1.4
# 325 contrast 0.3
# 326 contrast 1.4
# 327 sharpness 5.0
# 328 sharpness 20.0
# 329 Color 0.0
# 330 Color 10.0
# 331 mirror origional
# ___________________ bewerken afbeelding 10 ___________________
# 332 brightness 0.3
# 333 brightness 1.4
# 334 contrast 0.3
# 335 contrast 1.4
# 336 sharpness 5.0
# 337 sharpness 20.0
# 338 Color 0.0
# 339 Color 10.0
# 340 mirror origional
# ___________________ bewerken afbeelding 11 ___________________
# 341 brightness 0.3
# 342 brightness 1.4
# 343 contrast 0.3
# 344 contrast 1.4
# 345 sharpness 5.0
# 346 sharpness 20.0
# 347 Color 0.0
# 348 Color 10.0
# 349 mirror origional
# ___________________ bewerken afbeelding 12 ___________________
# 350 brightness 0.3
# 351 brightness 1.4
# 352 contrast 0.3
# 353 contrast 1.4
# 354 sharpness 5.0
# 355 sharpness 20.0
# 356 Color 0.0
# 357 Color 10.0
# 358 mirror origional
# ___________________ bewerken afbeelding 13 ___________________
# 359 brightness 0.3
# 360 brightness 1.4
# 361 contrast 0.3
# 362 contrast 1.4
# 363 sharpness 5.0
# 364 sharpness 20.0
# 365 Color 0.0
# 366 Color 10.0
# 367 mirror origional
# ___________________ bewerken afbeelding 14 ___________________
# 368 brightness 0.3
# 369 brightness 1.4
# 370 contrast 0.3
# 371 contrast 1.4
# 372 sharpness 5.0
# 373 sharpness 20.0
# 374 Color 0.0
# 375 Color 10.0
# 376 mirror origional
# ___________________ bewerken afbeelding 15 ___________________
# 377 brightness 0.3
# 378 brightness 1.4
# 379 contrast 0.3
# 380 contrast 1.4
# 381 sharpness 5.0
# 382 sharpness 20.0
# 383 Color 0.0
# 384 Color 10.0
# 385 mirror origional
# ___________________ bewerken afbeelding 16 ___________________
# 386 brightness 0.3
# 387 brightness 1.4
# 388 contrast 0.3
# 389 contrast 1.4
# 390 sharpness 5.0
# 391 sharpness 20.0
# 392 Color 0.0
# 393 Color 10.0
# 394 mirror origional
# ___________________ bewerken afbeelding 17 ___________________
# 395 brightness 0.3
# 396 brightness 1.4
# 397 contrast 0.3
# 398 contrast 1.4
# 399 sharpness 5.0
# 400 sharpness 20.0
# 401 Color 0.0
# 402 Color 10.0
# 403 mirror origional
# ___________________ bewerken afbeelding 18 ___________________
# 404 brightness 0.3
# 405 brightness 1.4
# 406 contrast 0.3
# 407 contrast 1.4
# 408 sharpness 5.0
# 409 sharpness 20.0
# 410 Color 0.0
# 411 Color 10.0
# 412 mirror origional
# ___________________ bewerken afbeelding 19 ___________________
# 413 brightness 0.3
# 414 brightness 1.4
# 415 contrast 0.3
# 416 contrast 1.4
# 417 sharpness 5.0
# 418 sharpness 20.0
# 419 Color 0.0
# 420 Color 10.0
# 421 mirror origional
# ___________________ bewerken afbeelding 20 ___________________
# 422 brightness 0.3
# 423 brightness 1.4
# 424 contrast 0.3
# 425 contrast 1.4
# 426 sharpness 5.0
# 427 sharpness 20.0
# 428 Color 0.0
# 429 Color 10.0
# 430 mirror origional
# ___________________ bewerken afbeelding 21 ___________________
# 431 brightness 0.3
# 432 brightness 1.4
# 433 contrast 0.3
# 434 contrast 1.4
# 435 sharpness 5.0
# 436 sharpness 20.0
# 437 Color 0.0
# 438 Color 10.0
# 439 mirror origional
# ___________________ bewerken afbeelding 22 ___________________
# 440 brightness 0.3
# 441 brightness 1.4
# 442 contrast 0.3
# 443 contrast 1.4
# 444 sharpness 5.0
# 445 sharpness 20.0
# 446 Color 0.0
# 447 Color 10.0
# 448 mirror origional
# ___________________ bewerken afbeelding 23 ___________________
# 449 brightness 0.3
# 450 brightness 1.4
# 451 contrast 0.3
# 452 contrast 1.4
# 453 sharpness 5.0
# 454 sharpness 20.0
# 455 Color 0.0
# 456 Color 10.0
# 457 mirror origional
# ___________________ bewerken afbeelding 24 ___________________
# 458 brightness 0.3
# 459 brightness 1.4
# 460 contrast 0.3
# 461 contrast 1.4
# 462 sharpness 5.0
# 463 sharpness 20.0
# 464 Color 0.0
# 465 Color 10.0
# 466 mirror origional
# ___________________ bewerken afbeelding 25 ___________________
# 467 brightness 0.3
# 468 brightness 1.4
# 469 contrast 0.3
# 470 contrast 1.4
# 471 sharpness 5.0
# 472 sharpness 20.0
# 473 Color 0.0
# 474 Color 10.0
# 475 mirror origional
# ___________________ bewerken afbeelding 26 ___________________
# 476 brightness 0.3
# 477 brightness 1.4
# 478 contrast 0.3
# 479 contrast 1.4
# 480 sharpness 5.0
# 481 sharpness 20.0
# 482 Color 0.0
# 483 Color 10.0
# 484 mirror origional
# ___________________ bewerken afbeelding 27 ___________________
# 485 brightness 0.3
# 486 brightness 1.4
# 487 contrast 0.3
# 488 contrast 1.4
# 489 sharpness 5.0
# 490 sharpness 20.0
# 491 Color 0.0
# 492 Color 10.0
# 493 mirror origional
# ___________________ bewerken afbeelding 28 ___________________
# 494 brightness 0.3
# 495 brightness 1.4
# 496 contrast 0.3
# 497 contrast 1.4
# 498 sharpness 5.0
# 499 sharpness 20.0
# 500 Color 0.0
# 501 Color 10.0
# 502 mirror origional
# ___________________ bewerken afbeelding 29 ___________________
# 503 brightness 0.3
# 504 brightness 1.4
# 505 contrast 0.3
# 506 contrast 1.4
# 507 sharpness 5.0
# 508 sharpness 20.0
# 509 Color 0.0
# 510 Color 10.0
# 511 mirror origional
# ___________________ bewerken afbeelding 30 ___________________
# 512 brightness 0.3
# 513 brightness 1.4
# 514 contrast 0.3
# 515 contrast 1.4
# 516 sharpness 5.0
# 517 sharpness 20.0
# 518 Color 0.0
# 519 Color 10.0
# 520 mirror origional
# ___________________ bewerken afbeelding 31 ___________________
# 521 brightness 0.3
# 522 brightness 1.4
# 523 contrast 0.3
# 524 contrast 1.4
# 525 sharpness 5.0
# 526 sharpness 20.0
# 527 Color 0.0
# 528 Color 10.0
# 529 mirror origional
# ___________________ bewerken afbeelding 32 ___________________
# 530 brightness 0.3
# 531 brightness 1.4
# 532 contrast 0.3
# 533 contrast 1.4
# 534 sharpness 5.0
# 535 sharpness 20.0
# 536 Color 0.0
# 537 Color 10.0
# 538 mirror origional
# ___________________ bewerken afbeelding 33 ___________________
# 539 brightness 0.3
# 540 brightness 1.4
# 541 contrast 0.3
# 542 contrast 1.4
# 543 sharpness 5.0
# 544 sharpness 20.0
# 545 Color 0.0
# 546 Color 10.0
# 547 mirror origional
# ___________________ bewerken afbeelding 34 ___________________
# 548 brightness 0.3
# 549 brightness 1.4
# 550 contrast 0.3
# 551 contrast 1.4
# 552 sharpness 5.0
# 553 sharpness 20.0
# 554 Color 0.0
# 555 Color 10.0
# 556 mirror origional
# ___________________ bewerken afbeelding 35 ___________________
# 557 brightness 0.3
# 558 brightness 1.4
# 559 contrast 0.3
# 560 contrast 1.4
# 561 sharpness 5.0
# 562 sharpness 20.0
# 563 Color 0.0
# 564 Color 10.0
# 565 mirror origional
# ___________________ bewerken afbeelding 36 ___________________
# 566 brightness 0.3
# 567 brightness 1.4
# 568 contrast 0.3
# 569 contrast 1.4
# 570 sharpness 5.0
# 571 sharpness 20.0
# 572 Color 0.0
# 573 Color 10.0
# 574 mirror origional
# ___________________ bewerken afbeelding 37 ___________________
# 575 brightness 0.3
# 576 brightness 1.4
# 577 contrast 0.3
# 578 contrast 1.4
# 579 sharpness 5.0
# 580 sharpness 20.0
# 581 Color 0.0
# 582 Color 10.0
# 583 mirror origional
# ___________________ bewerken afbeelding 38 ___________________
# 584 brightness 0.3
# 585 brightness 1.4
# 586 contrast 0.3
# 587 contrast 1.4
# 588 sharpness 5.0
# 589 sharpness 20.0
# 590 Color 0.0
# 591 Color 10.0
# 592 mirror origional
# ___________________ bewerken afbeelding 39 ___________________
# 593 brightness 0.3
# 594 brightness 1.4
# 595 contrast 0.3
# 596 contrast 1.4
# 597 sharpness 5.0
# 598 sharpness 20.0
# 599 Color 0.0
# 600 Color 10.0
# 601 mirror origional
# ___________________ bewerken afbeelding 40 ___________________
# 602 brightness 0.3
# 603 brightness 1.4
# 604 contrast 0.3
# 605 contrast 1.4
# 606 sharpness 5.0
# 607 sharpness 20.0
# 608 Color 0.0
# 609 Color 10.0
# 610 mirror origional
# ___________________ bewerken afbeelding 41 ___________________
# 611 brightness 0.3
# 612 brightness 1.4
# 613 contrast 0.3
# 614 contrast 1.4
# 615 sharpness 5.0
# 616 sharpness 20.0
# 617 Color 0.0
# 618 Color 10.0
# 619 mirror origional
# ___________________ bewerken afbeelding 42 ___________________
# 620 brightness 0.3
# 621 brightness 1.4
# 622 contrast 0.3
# 623 contrast 1.4
# 624 sharpness 5.0
# 625 sharpness 20.0
# 626 Color 0.0
# 627 Color 10.0
# 628 mirror origional
# ___________________ bewerken afbeelding 43 ___________________
# 629 brightness 0.3
# 630 brightness 1.4
# 631 contrast 0.3
# 632 contrast 1.4
# 633 sharpness 5.0
# 634 sharpness 20.0
# 635 Color 0.0
# 636 Color 10.0
# 637 mirror origional
# ___________________ bewerken afbeelding 44 ___________________
# 638 brightness 0.3
# 639 brightness 1.4
# 640 contrast 0.3
# 641 contrast 1.4
# 642 sharpness 5.0
# 643 sharpness 20.0
# 644 Color 0.0
# 645 Color 10.0
# 646 mirror origional
# ___________________ bewerken afbeelding 45 ___________________
# 647 brightness 0.3
# 648 brightness 1.4
# 649 contrast 0.3
# 650 contrast 1.4
# 651 sharpness 5.0
# 652 sharpness 20.0
# 653 Color 0.0
# 654 Color 10.0
# 655 mirror origional
# ___________________ bewerken afbeelding 46 ___________________
# 656 brightness 0.3
# 657 brightness 1.4
# 658 contrast 0.3
# 659 contrast 1.4
# 660 sharpness 5.0
# 661 sharpness 20.0
# 662 Color 0.0
# 663 Color 10.0
# 664 mirror origional
# ___________________ bewerken afbeelding 47 ___________________
# 665 brightness 0.3
# 666 brightness 1.4
# 667 contrast 0.3
# 668 contrast 1.4
# 669 sharpness 5.0
# 670 sharpness 20.0
# 671 Color 0.0
# 672 Color 10.0
# 673 mirror origional
# ___________________ bewerken afbeelding 48 ___________________
# 674 brightness 0.3
# 675 brightness 1.4
# 676 contrast 0.3
# 677 contrast 1.4
# 678 sharpness 5.0
# 679 sharpness 20.0
# 680 Color 0.0
# 681 Color 10.0
# 682 mirror origional
# ___________________ bewerken afbeelding 49 ___________________
# 683 brightness 0.3
# 684 brightness 1.4
# 685 contrast 0.3
# 686 contrast 1.4
# 687 sharpness 5.0
# 688 sharpness 20.0
# 689 Color 0.0
# 690 Color 10.0
# 691 mirror origional
# ___________________ bewerken afbeelding 50 ___________________
# 692 brightness 0.3
# 693 brightness 1.4
# 694 contrast 0.3
# 695 contrast 1.4
# 696 sharpness 5.0
# 697 sharpness 20.0
# 698 Color 0.0
# 699 Color 10.0
# 700 mirror origional
# ___________________ bewerken afbeelding 51 ___________________
# 701 brightness 0.3
# 702 brightness 1.4
# 703 contrast 0.3
# 704 contrast 1.4
# 705 sharpness 5.0
# 706 sharpness 20.0
# 707 Color 0.0
# 708 Color 10.0
# 709 mirror origional
# ___________________ bewerken afbeelding 52 ___________________
# 710 brightness 0.3
# 711 brightness 1.4
# 712 contrast 0.3
# 713 contrast 1.4
# 714 sharpness 5.0
# 715 sharpness 20.0
# 716 Color 0.0
# 717 Color 10.0
# 718 mirror origional
# ___________________ bewerken afbeelding 53 ___________________
# 719 brightness 0.3
# 720 brightness 1.4
# 721 contrast 0.3
# 722 contrast 1.4
# 723 sharpness 5.0
# 724 sharpness 20.0
# 725 Color 0.0
# 726 Color 10.0
# 727 mirror origional
# ___________________ bewerken afbeelding 54 ___________________
# 728 brightness 0.3
# 729 brightness 1.4
# 730 contrast 0.3
# 731 contrast 1.4
# 732 sharpness 5.0
# 733 sharpness 20.0
# 734 Color 0.0
# 735 Color 10.0
# 736 mirror origional
# ___________________ bewerken afbeelding 55 ___________________
# 737 brightness 0.3
# 738 brightness 1.4
# 739 contrast 0.3
# 740 contrast 1.4
# 741 sharpness 5.0
# 742 sharpness 20.0
# 743 Color 0.0
# 744 Color 10.0
# 745 mirror origional
# ___________________ bewerken afbeelding 56 ___________________
# 746 brightness 0.3
# 747 brightness 1.4
# 748 contrast 0.3
# 749 contrast 1.4
# 750 sharpness 5.0
# 751 sharpness 20.0
# 752 Color 0.0
# 753 Color 10.0
# 754 mirror origional
# ___________________ bewerken afbeelding 57 ___________________
# 755 brightness 0.3
# 756 brightness 1.4
# 757 contrast 0.3
# 758 contrast 1.4
# 759 sharpness 5.0
# 760 sharpness 20.0
# 761 Color 0.0
# 762 Color 10.0
# 763 mirror origional
# ___________________ bewerken afbeelding 58 ___________________
# 764 brightness 0.3
# 765 brightness 1.4
# 766 contrast 0.3
# 767 contrast 1.4
# 768 sharpness 5.0
# 769 sharpness 20.0
# 770 Color 0.0
# 771 Color 10.0
# 772 mirror origional
# ___________________ bewerken afbeelding 59 ___________________
# 773 brightness 0.3
# 774 brightness 1.4
# 775 contrast 0.3
# 776 contrast 1.4
# 777 sharpness 5.0
# 778 sharpness 20.0
# 779 Color 0.0
# 780 Color 10.0
# 781 mirror origional
# ___________________ bewerken afbeelding 60 ___________________
# 782 brightness 0.3
# 783 brightness 1.4
# 784 contrast 0.3
# 785 contrast 1.4
# 786 sharpness 5.0
# 787 sharpness 20.0
# 788 Color 0.0
# 789 Color 10.0
# 790 mirror origional
# ___________________ bewerken afbeelding 61 ___________________
# 791 brightness 0.3
# 792 brightness 1.4
# 793 contrast 0.3
# 794 contrast 1.4
# 795 sharpness 5.0
# 796 sharpness 20.0
# 797 Color 0.0
# 798 Color 10.0
# 799 mirror origional
# ___________________ bewerken afbeelding 62 ___________________
# 800 brightness 0.3
# 801 brightness 1.4
# 802 contrast 0.3
# 803 contrast 1.4
# 804 sharpness 5.0
# 805 sharpness 20.0
# 806 Color 0.0
# 807 Color 10.0
# 808 mirror origional
# ___________________ bewerken afbeelding 63 ___________________
# 809 brightness 0.3
# 810 brightness 1.4
# 811 contrast 0.3
# 812 contrast 1.4
# 813 sharpness 5.0
# 814 sharpness 20.0
# 815 Color 0.0
# 816 Color 10.0
# 817 mirror origional
# ___________________ bewerken afbeelding 64 ___________________
# 818 brightness 0.3
# 819 brightness 1.4
# 820 contrast 0.3
# 821 contrast 1.4
# 822 sharpness 5.0
# 823 sharpness 20.0
# 824 Color 0.0
# 825 Color 10.0
# 826 mirror origional
# ___________________ bewerken afbeelding 65 ___________________
# 827 brightness 0.3
# 828 brightness 1.4
# 829 contrast 0.3
# 830 contrast 1.4
# 831 sharpness 5.0
# 832 sharpness 20.0
# 833 Color 0.0
# 834 Color 10.0
# 835 mirror origional
# ___________________ bewerken afbeelding 66 ___________________
# 836 brightness 0.3
# 837 brightness 1.4
# 838 contrast 0.3
# 839 contrast 1.4
# 840 sharpness 5.0
# 841 sharpness 20.0
# 842 Color 0.0
# 843 Color 10.0
# 844 mirror origional
# ___________________ bewerken afbeelding 67 ___________________
# 845 brightness 0.3
# 846 brightness 1.4
# 847 contrast 0.3
# 848 contrast 1.4
# 849 sharpness 5.0
# 850 sharpness 20.0
# 851 Color 0.0
# 852 Color 10.0
# 853 mirror origional
# ___________________ bewerken afbeelding 68 ___________________
# 854 brightness 0.3
# 855 brightness 1.4
# 856 contrast 0.3
# 857 contrast 1.4
# 858 sharpness 5.0
# 859 sharpness 20.0
# 860 Color 0.0
# 861 Color 10.0
# 862 mirror origional
# ___________________ bewerken afbeelding 69 ___________________
# 863 brightness 0.3
# 864 brightness 1.4
# 865 contrast 0.3
# 866 contrast 1.4
# 867 sharpness 5.0
# 868 sharpness 20.0
# 869 Color 0.0
# 870 Color 10.0
# 871 mirror origional
# ___________________ bewerken afbeelding 70 ___________________
# 872 brightness 0.3
# 873 brightness 1.4
# 874 contrast 0.3
# 875 contrast 1.4
# 876 sharpness 5.0
# 877 sharpness 20.0
# 878 Color 0.0
# 879 Color 10.0
# 880 mirror origional
# ___________________ bewerken afbeelding 71 ___________________
# 881 brightness 0.3
# 882 brightness 1.4
# 883 contrast 0.3
# 884 contrast 1.4
# 885 sharpness 5.0
# 886 sharpness 20.0
# 887 Color 0.0
# 888 Color 10.0
# 889 mirror origional
# ___________________ bewerken afbeelding 72 ___________________
# 890 brightness 0.3
# 891 brightness 1.4
# 892 contrast 0.3
# 893 contrast 1.4
# 894 sharpness 5.0
# 895 sharpness 20.0
# 896 Color 0.0
# 897 Color 10.0
# 898 mirror origional
# ___________________ bewerken afbeelding 73 ___________________
# 899 brightness 0.3
# 900 brightness 1.4
# 901 contrast 0.3
# 902 contrast 1.4
# 903 sharpness 5.0
# 904 sharpness 20.0
# 905 Color 0.0
# 906 Color 10.0
# 907 mirror origional
# ___________________ bewerken afbeelding 74 ___________________
# 908 brightness 0.3
# 909 brightness 1.4
# 910 contrast 0.3
# 911 contrast 1.4
# 912 sharpness 5.0
# 913 sharpness 20.0
# 914 Color 0.0
# 915 Color 10.0
# 916 mirror origional
# ___________________ bewerken afbeelding 75 ___________________
# 917 brightness 0.3
# 918 brightness 1.4
# 919 contrast 0.3
# 920 contrast 1.4
# 921 sharpness 5.0
# 922 sharpness 20.0
# 923 Color 0.0
# 924 Color 10.0
# 925 mirror origional
# ___________________ bewerken afbeelding 76 ___________________
# 926 brightness 0.3
# 927 brightness 1.4
# 928 contrast 0.3
# 929 contrast 1.4
# 930 sharpness 5.0
# 931 sharpness 20.0
# 932 Color 0.0
# 933 Color 10.0
# 934 mirror origional
# ___________________ bewerken afbeelding 77 ___________________
# 935 brightness 0.3
# 936 brightness 1.4
# 937 contrast 0.3
# 938 contrast 1.4
# 939 sharpness 5.0
# 940 sharpness 20.0
# 941 Color 0.0
# 942 Color 10.0
# 943 mirror origional
# ___________________ bewerken afbeelding 78 ___________________
# 944 brightness 0.3
# 945 brightness 1.4
# 946 contrast 0.3
# 947 contrast 1.4
# 948 sharpness 5.0
# 949 sharpness 20.0
# 950 Color 0.0
# 951 Color 10.0
# 952 mirror origional
# ___________________ bewerken afbeelding 79 ___________________
# 953 brightness 0.3
# 954 brightness 1.4
# 955 contrast 0.3
# 956 contrast 1.4
# 957 sharpness 5.0
# 958 sharpness 20.0
# 959 Color 0.0
# 960 Color 10.0
# 961 mirror origional
# ___________________ bewerken afbeelding 80 ___________________
# 962 brightness 0.3
# 963 brightness 1.4
# 964 contrast 0.3
# 965 contrast 1.4
# 966 sharpness 5.0
# 967 sharpness 20.0
# 968 Color 0.0
# 969 Color 10.0
# 970 mirror origional
# ___________________ bewerken afbeelding 81 ___________________
# 971 brightness 0.3
# 972 brightness 1.4
# 973 contrast 0.3
# 974 contrast 1.4
# 975 sharpness 5.0
# 976 sharpness 20.0
# 977 Color 0.0
# 978 Color 10.0
# 979 mirror origional
# ___________________ bewerken afbeelding 82 ___________________
# 980 brightness 0.3
# 981 brightness 1.4
# 982 contrast 0.3
# 983 contrast 1.4
# 984 sharpness 5.0
# 985 sharpness 20.0
# 986 Color 0.0
# 987 Color 10.0
# 988 mirror origional
# ___________________ bewerken afbeelding 83 ___________________
# 989 brightness 0.3
# 990 brightness 1.4
# 991 contrast 0.3
# 992 contrast 1.4
# 993 sharpness 5.0
# 994 sharpness 20.0
# 995 Color 0.0
# 996 Color 10.0
# 997 mirror origional
# ___________________ bewerken afbeelding 84 ___________________
# 998 brightness 0.3
# 999 brightness 1.4
# 1000 contrast 0.3
# 1001 contrast 1.4
# 1002 sharpness 5.0
# 1003 sharpness 20.0
# 1004 Color 0.0
# 1005 Color 10.0
# 1006 mirror origional
# ___________________ bewerken afbeelding 85 ___________________
# 1007 brightness 0.3
# 1008 brightness 1.4
# 1009 contrast 0.3
# 1010 contrast 1.4
# 1011 sharpness 5.0
# 1012 sharpness 20.0
# 1013 Color 0.0
# 1014 Color 10.0
# 1015 mirror origional
# ___________________ bewerken afbeelding 86 ___________________
# 1016 brightness 0.3
# 1017 brightness 1.4
# 1018 contrast 0.3
# 1019 contrast 1.4
# 1020 sharpness 5.0
# 1021 sharpness 20.0
# 1022 Color 0.0
# 1023 Color 10.0
# 1024 mirror origional
# ___________________ bewerken afbeelding 87 ___________________
# 1025 brightness 0.3
# 1026 brightness 1.4
# 1027 contrast 0.3
# 1028 contrast 1.4
# 1029 sharpness 5.0
# 1030 sharpness 20.0
# 1031 Color 0.0
# 1032 Color 10.0
# 1033 mirror origional
# ___________________ bewerken afbeelding 88 ___________________
# 1034 brightness 0.3
# 1035 brightness 1.4
# 1036 contrast 0.3
# 1037 contrast 1.4
# 1038 sharpness 5.0
# 1039 sharpness 20.0
# 1040 Color 0.0
# 1041 Color 10.0
# 1042 mirror origional
# ___________________ bewerken afbeelding 89 ___________________
# 1043 brightness 0.3
# 1044 brightness 1.4
# 1045 contrast 0.3
# 1046 contrast 1.4
# 1047 sharpness 5.0
# 1048 sharpness 20.0
# 1049 Color 0.0
# 1050 Color 10.0
# 1051 mirror origional
# ___________________ bewerken afbeelding 90 ___________________
# 1052 brightness 0.3
# 1053 brightness 1.4
# 1054 contrast 0.3
# 1055 contrast 1.4
# 1056 sharpness 5.0
# 1057 sharpness 20.0
# 1058 Color 0.0
# 1059 Color 10.0
# 1060 mirror origional
# ___________________ bewerken afbeelding 91 ___________________
# 1061 brightness 0.3
# 1062 brightness 1.4
# 1063 contrast 0.3
# 1064 contrast 1.4
# 1065 sharpness 5.0
# 1066 sharpness 20.0
# 1067 Color 0.0
# 1068 Color 10.0
# 1069 mirror origional
# ___________________ bewerken afbeelding 92 ___________________
# 1070 brightness 0.3
# 1071 brightness 1.4
# 1072 contrast 0.3
# 1073 contrast 1.4
# 1074 sharpness 5.0
# 1075 sharpness 20.0
# 1076 Color 0.0
# 1077 Color 10.0
# 1078 mirror origional
# ___________________ bewerken afbeelding 93 ___________________
# 1079 brightness 0.3
# 1080 brightness 1.4
# 1081 contrast 0.3
# 1082 contrast 1.4
# 1083 sharpness 5.0
# 1084 sharpness 20.0
# 1085 Color 0.0
# 1086 Color 10.0
# 1087 mirror origional
# ___________________ bewerken afbeelding 94 ___________________
# 1088 brightness 0.3
# 1089 brightness 1.4
# 1090 contrast 0.3
# 1091 contrast 1.4
# 1092 sharpness 5.0
# 1093 sharpness 20.0
# 1094 Color 0.0
# 1095 Color 10.0
# 1096 mirror origional
# ___________________ bewerken afbeelding 95 ___________________
# 1097 brightness 0.3
# 1098 brightness 1.4
# 1099 contrast 0.3
# 1100 contrast 1.4
# 1101 sharpness 5.0
# 1102 sharpness 20.0
# 1103 Color 0.0
# 1104 Color 10.0
# 1105 mirror origional
# ___________________ bewerken afbeelding 96 ___________________
# 1106 brightness 0.3
# 1107 brightness 1.4
# 1108 contrast 0.3
# 1109 contrast 1.4
# 1110 sharpness 5.0
# 1111 sharpness 20.0
# 1112 Color 0.0
# 1113 Color 10.0
# 1114 mirror origional
# ___________________ bewerken afbeelding 97 ___________________
# 1115 brightness 0.3
# 1116 brightness 1.4
# 1117 contrast 0.3
# 1118 contrast 1.4
# 1119 sharpness 5.0
# 1120 sharpness 20.0
# 1121 Color 0.0
# 1122 Color 10.0
# 1123 mirror origional
# ___________________ bewerken afbeelding 98 ___________________
# 1124 brightness 0.3
# 1125 brightness 1.4
# 1126 contrast 0.3
# 1127 contrast 1.4
# 1128 sharpness 5.0
# 1129 sharpness 20.0
# 1130 Color 0.0
# 1131 Color 10.0
# 1132 mirror origional
# ___________________ bewerken afbeelding 99 ___________________
# 1133 brightness 0.3
# 1134 brightness 1.4
# 1135 contrast 0.3
# 1136 contrast 1.4
# 1137 sharpness 5.0
# 1138 sharpness 20.0
# 1139 Color 0.0
# 1140 Color 10.0
# 1141 mirror origional
# ___________________ bewerken afbeelding 100 ___________________
# 1142 brightness 0.3
# 1143 brightness 1.4
# 1144 contrast 0.3
# 1145 contrast 1.4
# 1146 sharpness 5.0
# 1147 sharpness 20.0
# 1148 Color 0.0
# 1149 Color 10.0
# 1150 mirror origional
# ___________________ bewerken afbeelding 101 ___________________
# 1151 brightness 0.3
# 1152 brightness 1.4
# 1153 contrast 0.3
# 1154 contrast 1.4
# 1155 sharpness 5.0
# 1156 sharpness 20.0
# 1157 Color 0.0
# 1158 Color 10.0
# 1159 mirror origional
# ___________________ bewerken afbeelding 102 ___________________
# 1160 brightness 0.3
# 1161 brightness 1.4
# 1162 contrast 0.3
# 1163 contrast 1.4
# 1164 sharpness 5.0
# 1165 sharpness 20.0
# 1166 Color 0.0
# 1167 Color 10.0
# 1168 mirror origional
# ___________________ bewerken afbeelding 103 ___________________
# 1169 brightness 0.3
# 1170 brightness 1.4
# 1171 contrast 0.3
# 1172 contrast 1.4
# 1173 sharpness 5.0
# 1174 sharpness 20.0
# 1175 Color 0.0
# 1176 Color 10.0
# 1177 mirror origional
# ___________________ bewerken afbeelding 104 ___________________
# 1178 brightness 0.3
# 1179 brightness 1.4
# 1180 contrast 0.3
# 1181 contrast 1.4
# 1182 sharpness 5.0
# 1183 sharpness 20.0
# 1184 Color 0.0
# 1185 Color 10.0
# 1186 mirror origional
# ___________________ bewerken afbeelding 105 ___________________
# 1187 brightness 0.3
# 1188 brightness 1.4
# 1189 contrast 0.3
# 1190 contrast 1.4
# 1191 sharpness 5.0
# 1192 sharpness 20.0
# 1193 Color 0.0
# 1194 Color 10.0
# 1195 mirror origional
# ___________________ bewerken afbeelding 106 ___________________
# 1196 brightness 0.3
# 1197 brightness 1.4
# 1198 contrast 0.3
# 1199 contrast 1.4
# 1200 sharpness 5.0
# 1201 sharpness 20.0
# 1202 Color 0.0
# 1203 Color 10.0
# 1204 mirror origional
# ___________________ bewerken afbeelding 107 ___________________
# 1205 brightness 0.3
# 1206 brightness 1.4
# 1207 contrast 0.3
# 1208 contrast 1.4
# 1209 sharpness 5.0
# 1210 sharpness 20.0
# 1211 Color 0.0
# 1212 Color 10.0
# 1213 mirror origional
# ___________________ bewerken afbeelding 108 ___________________
# 1214 brightness 0.3
# 1215 brightness 1.4
# 1216 contrast 0.3
# 1217 contrast 1.4
# 1218 sharpness 5.0
# 1219 sharpness 20.0
# 1220 Color 0.0
# 1221 Color 10.0
# 1222 mirror origional
# ___________________ bewerken afbeelding 109 ___________________
# 1223 brightness 0.3
# 1224 brightness 1.4
# 1225 contrast 0.3
# 1226 contrast 1.4
# 1227 sharpness 5.0
# 1228 sharpness 20.0
# 1229 Color 0.0
# 1230 Color 10.0
# 1231 mirror origional
# ___________________ bewerken afbeelding 110 ___________________
# 1232 brightness 0.3
# 1233 brightness 1.4
# 1234 contrast 0.3
# 1235 contrast 1.4
# 1236 sharpness 5.0
# 1237 sharpness 20.0
# 1238 Color 0.0
# 1239 Color 10.0
# 1240 mirror origional
# ___________________ bewerken afbeelding 111 ___________________
# 1241 brightness 0.3
# 1242 brightness 1.4
# 1243 contrast 0.3
# 1244 contrast 1.4
# 1245 sharpness 5.0
# 1246 sharpness 20.0
# 1247 Color 0.0
# 1248 Color 10.0
# 1249 mirror origional
# ___________________ bewerken afbeelding 112 ___________________
# 1250 brightness 0.3
# 1251 brightness 1.4
# 1252 contrast 0.3
# 1253 contrast 1.4
# 1254 sharpness 5.0
# 1255 sharpness 20.0
# 1256 Color 0.0
# 1257 Color 10.0
# 1258 mirror origional
# ___________________ bewerken afbeelding 113 ___________________
# 1259 brightness 0.3
# 1260 brightness 1.4
# 1261 contrast 0.3
# 1262 contrast 1.4
# 1263 sharpness 5.0
# 1264 sharpness 20.0
# 1265 Color 0.0
# 1266 Color 10.0
# 1267 mirror origional
# ___________________ bewerken afbeelding 114 ___________________
# 1268 brightness 0.3
# 1269 brightness 1.4
# 1270 contrast 0.3
# 1271 contrast 1.4
# 1272 sharpness 5.0
# 1273 sharpness 20.0
# 1274 Color 0.0
# 1275 Color 10.0
# 1276 mirror origional
# ___________________ bewerken afbeelding 115 ___________________
# 1277 brightness 0.3
# 1278 brightness 1.4
# 1279 contrast 0.3
# 1280 contrast 1.4
# 1281 sharpness 5.0
# 1282 sharpness 20.0
# 1283 Color 0.0
# 1284 Color 10.0
# 1285 mirror origional
# ___________________ bewerken afbeelding 116 ___________________
# 1286 brightness 0.3
# 1287 brightness 1.4
# 1288 contrast 0.3
# 1289 contrast 1.4
# 1290 sharpness 5.0
# 1291 sharpness 20.0
# 1292 Color 0.0
# 1293 Color 10.0
# 1294 mirror origional
# ___________________ bewerken afbeelding 117 ___________________
# 1295 brightness 0.3
# 1296 brightness 1.4
# 1297 contrast 0.3
# 1298 contrast 1.4
# 1299 sharpness 5.0
# 1300 sharpness 20.0
# 1301 Color 0.0
# 1302 Color 10.0
# 1303 mirror origional
# ___________________ bewerken afbeelding 118 ___________________
# 1304 brightness 0.3
# 1305 brightness 1.4
# 1306 contrast 0.3
# 1307 contrast 1.4
# 1308 sharpness 5.0
# 1309 sharpness 20.0
# 1310 Color 0.0
# 1311 Color 10.0
# 1312 mirror origional
# ___________________ bewerken afbeelding 119 ___________________
# 1313 brightness 0.3
# 1314 brightness 1.4
# 1315 contrast 0.3
# 1316 contrast 1.4
# 1317 sharpness 5.0
# 1318 sharpness 20.0
# 1319 Color 0.0
# 1320 Color 10.0
# 1321 mirror origional
# ___________________ bewerken afbeelding 120 ___________________
# 1322 brightness 0.3
# 1323 brightness 1.4
# 1324 contrast 0.3
# 1325 contrast 1.4
# 1326 sharpness 5.0
# 1327 sharpness 20.0
# 1328 Color 0.0
# 1329 Color 10.0
# 1330 mirror origional
# ___________________ bewerken afbeelding 121 ___________________
# 1331 brightness 0.3
# 1332 brightness 1.4
# 1333 contrast 0.3
# 1334 contrast 1.4
# 1335 sharpness 5.0
# 1336 sharpness 20.0
# 1337 Color 0.0
# 1338 Color 10.0
# 1339 mirror origional
# ___________________ bewerken afbeelding 122 ___________________
# 1340 brightness 0.3
# 1341 brightness 1.4
# 1342 contrast 0.3
# 1343 contrast 1.4
# 1344 sharpness 5.0
# 1345 sharpness 20.0
# 1346 Color 0.0
# 1347 Color 10.0
# 1348 mirror origional
# ___________________ bewerken afbeelding 123 ___________________
# 1349 brightness 0.3
# 1350 brightness 1.4
# 1351 contrast 0.3
# 1352 contrast 1.4
# 1353 sharpness 5.0
# 1354 sharpness 20.0
# 1355 Color 0.0
# 1356 Color 10.0
# 1357 mirror origional
# ___________________ bewerken afbeelding 124 ___________________
# 1358 brightness 0.3
# 1359 brightness 1.4
# 1360 contrast 0.3
# 1361 contrast 1.4
# 1362 sharpness 5.0
# 1363 sharpness 20.0
# 1364 Color 0.0
# 1365 Color 10.0
# 1366 mirror origional
# ___________________ bewerken afbeelding 125 ___________________
# 1367 brightness 0.3
# 1368 brightness 1.4
# 1369 contrast 0.3
# 1370 contrast 1.4
# 1371 sharpness 5.0
# 1372 sharpness 20.0
# 1373 Color 0.0
# 1374 Color 10.0
# 1375 mirror origional
# ___________________ bewerken afbeelding 126 ___________________
# 1376 brightness 0.3
# 1377 brightness 1.4
# 1378 contrast 0.3
# 1379 contrast 1.4
# 1380 sharpness 5.0
# 1381 sharpness 20.0
# 1382 Color 0.0
# 1383 Color 10.0
# 1384 mirror origional
# ___________________ bewerken afbeelding 127 ___________________
# 1385 brightness 0.3
# 1386 brightness 1.4
# 1387 contrast 0.3
# 1388 contrast 1.4
# 1389 sharpness 5.0
# 1390 sharpness 20.0
# 1391 Color 0.0
# 1392 Color 10.0
# 1393 mirror origional
# ___________________ bewerken afbeelding 128 ___________________
# 1394 brightness 0.3
# 1395 brightness 1.4
# 1396 contrast 0.3
# 1397 contrast 1.4
# 1398 sharpness 5.0
# 1399 sharpness 20.0
# 1400 Color 0.0
# 1401 Color 10.0
# 1402 mirror origional
# ___________________ bewerken afbeelding 129 ___________________
# 1403 brightness 0.3
# 1404 brightness 1.4
# 1405 contrast 0.3
# 1406 contrast 1.4
# 1407 sharpness 5.0
# 1408 sharpness 20.0
# 1409 Color 0.0
# 1410 Color 10.0
# 1411 mirror origional
# ___________________ bewerken afbeelding 130 ___________________
# 1412 brightness 0.3
# 1413 brightness 1.4
# 1414 contrast 0.3
# 1415 contrast 1.4
# 1416 sharpness 5.0
# 1417 sharpness 20.0
# 1418 Color 0.0
# 1419 Color 10.0
# 1420 mirror origional
# ___________________ bewerken afbeelding 131 ___________________
# 1421 brightness 0.3
# 1422 brightness 1.4
# 1423 contrast 0.3
# 1424 contrast 1.4
# 1425 sharpness 5.0
# 1426 sharpness 20.0
# 1427 Color 0.0
# 1428 Color 10.0
# 1429 mirror origional
# ___________________ bewerken afbeelding 132 ___________________
# 1430 brightness 0.3
# 1431 brightness 1.4
# 1432 contrast 0.3
# 1433 contrast 1.4
# 1434 sharpness 5.0
# 1435 sharpness 20.0
# 1436 Color 0.0
# 1437 Color 10.0
# 1438 mirror origional
# ___________________ bewerken afbeelding 133 ___________________
# 1439 brightness 0.3
# 1440 brightness 1.4
# 1441 contrast 0.3
# 1442 contrast 1.4
# 1443 sharpness 5.0
# 1444 sharpness 20.0
# 1445 Color 0.0
# 1446 Color 10.0
# 1447 mirror origional
# ___________________ bewerken afbeelding 134 ___________________
# 1448 brightness 0.3
# 1449 brightness 1.4
# 1450 contrast 0.3
# 1451 contrast 1.4
# 1452 sharpness 5.0
# 1453 sharpness 20.0
# 1454 Color 0.0
# 1455 Color 10.0
# 1456 mirror origional
# ___________________ bewerken afbeelding 135 ___________________
# 1457 brightness 0.3
# 1458 brightness 1.4
# 1459 contrast 0.3
# 1460 contrast 1.4
# 1461 sharpness 5.0
# 1462 sharpness 20.0
# 1463 Color 0.0
# 1464 Color 10.0
# 1465 mirror origional
# ___________________ bewerken afbeelding 136 ___________________
# 1466 brightness 0.3
# 1467 brightness 1.4
# 1468 contrast 0.3
# 1469 contrast 1.4
# 1470 sharpness 5.0
# 1471 sharpness 20.0
# 1472 Color 0.0
# 1473 Color 10.0
# 1474 mirror origional
# ___________________ bewerken afbeelding 137 ___________________
# 1475 brightness 0.3
# 1476 brightness 1.4
# 1477 contrast 0.3
# 1478 contrast 1.4
# 1479 sharpness 5.0
# 1480 sharpness 20.0
# 1481 Color 0.0
# 1482 Color 10.0
# 1483 mirror origional
# ___________________ bewerken afbeelding 138 ___________________
# 1484 brightness 0.3
# 1485 brightness 1.4
# 1486 contrast 0.3
# 1487 contrast 1.4
# 1488 sharpness 5.0
# 1489 sharpness 20.0
# 1490 Color 0.0
# 1491 Color 10.0
# 1492 mirror origional
# ___________________ bewerken afbeelding 139 ___________________
# 1493 brightness 0.3
# 1494 brightness 1.4
# 1495 contrast 0.3
# 1496 contrast 1.4
# 1497 sharpness 5.0
# 1498 sharpness 20.0
# 1499 Color 0.0
# 1500 Color 10.0
# 1501 mirror origional
# ___________________ bewerken afbeelding 140 ___________________
# 1502 brightness 0.3
# 1503 brightness 1.4
# 1504 contrast 0.3
# 1505 contrast 1.4
# 1506 sharpness 5.0
# 1507 sharpness 20.0
# 1508 Color 0.0
# 1509 Color 10.0
# 1510 mirror origional
# ___________________ bewerken afbeelding 141 ___________________
# 1511 brightness 0.3
# 1512 brightness 1.4
# 1513 contrast 0.3
# 1514 contrast 1.4
# 1515 sharpness 5.0
# 1516 sharpness 20.0
# 1517 Color 0.0
# 1518 Color 10.0
# 1519 mirror origional
# ___________________ bewerken afbeelding 142 ___________________
# 1520 brightness 0.3
# 1521 brightness 1.4
# 1522 contrast 0.3
# 1523 contrast 1.4
# 1524 sharpness 5.0
# 1525 sharpness 20.0
# 1526 Color 0.0
# 1527 Color 10.0
# 1528 mirror origional
# ___________________ bewerken afbeelding 143 ___________________
# 1529 brightness 0.3
# 1530 brightness 1.4
# 1531 contrast 0.3
# 1532 contrast 1.4
# 1533 sharpness 5.0
# 1534 sharpness 20.0
# 1535 Color 0.0
# 1536 Color 10.0
# 1537 mirror origional
# ___________________ bewerken afbeelding 144 ___________________
# 1538 brightness 0.3
# 1539 brightness 1.4
# 1540 contrast 0.3
# 1541 contrast 1.4
# 1542 sharpness 5.0
# 1543 sharpness 20.0
# 1544 Color 0.0
# 1545 Color 10.0
# 1546 mirror origional
# ___________________ bewerken afbeelding 145 ___________________
# 1547 brightness 0.3
# 1548 brightness 1.4
# 1549 contrast 0.3
# 1550 contrast 1.4
# 1551 sharpness 5.0
# 1552 sharpness 20.0
# 1553 Color 0.0
# 1554 Color 10.0
# 1555 mirror origional
# ___________________ bewerken afbeelding 146 ___________________
# 1556 brightness 0.3
# 1557 brightness 1.4
# 1558 contrast 0.3
# 1559 contrast 1.4
# 1560 sharpness 5.0
# 1561 sharpness 20.0
# 1562 Color 0.0
# 1563 Color 10.0
# 1564 mirror origional
# ___________________ bewerken afbeelding 147 ___________________
# 1565 brightness 0.3
# 1566 brightness 1.4
# 1567 contrast 0.3
# 1568 contrast 1.4
# 1569 sharpness 5.0
# 1570 sharpness 20.0
# 1571 Color 0.0
# 1572 Color 10.0
# 1573 mirror origional
# ___________________ bewerken afbeelding 148 ___________________
# 1574 brightness 0.3
# 1575 brightness 1.4
# 1576 contrast 0.3
# 1577 contrast 1.4
# 1578 sharpness 5.0
# 1579 sharpness 20.0
# 1580 Color 0.0
# 1581 Color 10.0
# 1582 mirror origional
# ___________________ bewerken afbeelding 149 ___________________
# 1583 brightness 0.3
# 1584 brightness 1.4
# 1585 contrast 0.3
# 1586 contrast 1.4
# 1587 sharpness 5.0
# 1588 sharpness 20.0
# 1589 Color 0.0
# 1590 Color 10.0
# 1591 mirror origional
# ___________________ bewerken afbeelding 150 ___________________
# 1592 brightness 0.3
# 1593 brightness 1.4
# 1594 contrast 0.3
# 1595 contrast 1.4
# 1596 sharpness 5.0
# 1597 sharpness 20.0
# 1598 Color 0.0
# 1599 Color 10.0
# 1600 mirror origional
# ___________________ bewerken afbeelding 151 ___________________
# 1601 brightness 0.3
# 1602 brightness 1.4
# 1603 contrast 0.3
# 1604 contrast 1.4
# 1605 sharpness 5.0
# 1606 sharpness 20.0
# 1607 Color 0.0
# 1608 Color 10.0
# 1609 mirror origional
# ___________________ bewerken afbeelding 152 ___________________
# 1610 brightness 0.3
# 1611 brightness 1.4
# 1612 contrast 0.3
# 1613 contrast 1.4
# 1614 sharpness 5.0
# 1615 sharpness 20.0
# 1616 Color 0.0
# 1617 Color 10.0
# 1618 mirror origional
# ___________________ bewerken afbeelding 153 ___________________
# 1619 brightness 0.3
# 1620 brightness 1.4
# 1621 contrast 0.3
# 1622 contrast 1.4
# 1623 sharpness 5.0
# 1624 sharpness 20.0
# 1625 Color 0.0
# 1626 Color 10.0
# 1627 mirror origional
# ___________________ bewerken afbeelding 154 ___________________
# 1628 brightness 0.3
# 1629 brightness 1.4
# 1630 contrast 0.3
# 1631 contrast 1.4
# 1632 sharpness 5.0
# 1633 sharpness 20.0
# 1634 Color 0.0
# 1635 Color 10.0
# 1636 mirror origional
# ___________________ bewerken afbeelding 155 ___________________
# 1637 brightness 0.3
# 1638 brightness 1.4
# 1639 contrast 0.3
# 1640 contrast 1.4
# 1641 sharpness 5.0
# 1642 sharpness 20.0
# 1643 Color 0.0
# 1644 Color 10.0
# 1645 mirror origional
# ___________________ bewerken afbeelding 156 ___________________
# 1646 brightness 0.3
# 1647 brightness 1.4
# 1648 contrast 0.3
# 1649 contrast 1.4
# 1650 sharpness 5.0
# 1651 sharpness 20.0
# 1652 Color 0.0
# 1653 Color 10.0
# 1654 mirror origional
# ___________________ bewerken afbeelding 157 ___________________
# 1655 brightness 0.3
# 1656 brightness 1.4
# 1657 contrast 0.3
# 1658 contrast 1.4
# 1659 sharpness 5.0
# 1660 sharpness 20.0
# 1661 Color 0.0
# 1662 Color 10.0
# 1663 mirror origional
# ___________________ bewerken afbeelding 158 ___________________
# 1664 brightness 0.3
# 1665 brightness 1.4
# 1666 contrast 0.3
# 1667 contrast 1.4
# 1668 sharpness 5.0
# 1669 sharpness 20.0
# 1670 Color 0.0
# 1671 Color 10.0
# 1672 mirror origional
# ___________________ bewerken afbeelding 159 ___________________
# 1673 brightness 0.3
# 1674 brightness 1.4
# 1675 contrast 0.3
# 1676 contrast 1.4
# 1677 sharpness 5.0
# 1678 sharpness 20.0
# 1679 Color 0.0
# 1680 Color 10.0
# 1681 mirror origional
# ___________________ bewerken afbeelding 160 ___________________
# 1682 brightness 0.3
# 1683 brightness 1.4
# 1684 contrast 0.3
# 1685 contrast 1.4
# 1686 sharpness 5.0
# 1687 sharpness 20.0
# 1688 Color 0.0
# 1689 Color 10.0
# 1690 mirror origional
# ___________________ bewerken afbeelding 161 ___________________
# 1691 brightness 0.3
# 1692 brightness 1.4
# 1693 contrast 0.3
# 1694 contrast 1.4
# 1695 sharpness 5.0
# 1696 sharpness 20.0
# 1697 Color 0.0
# 1698 Color 10.0
# 1699 mirror origional
# ___________________ bewerken afbeelding 162 ___________________
# 1700 brightness 0.3
# 1701 brightness 1.4
# 1702 contrast 0.3
# 1703 contrast 1.4
# 1704 sharpness 5.0
# 1705 sharpness 20.0
# 1706 Color 0.0
# 1707 Color 10.0
# 1708 mirror origional
# ___________________ bewerken afbeelding 163 ___________________
# 1709 brightness 0.3
# 1710 brightness 1.4
# 1711 contrast 0.3
# 1712 contrast 1.4
# 1713 sharpness 5.0
# 1714 sharpness 20.0
# 1715 Color 0.0
# 1716 Color 10.0
# 1717 mirror origional
# ___________________ bewerken afbeelding 164 ___________________
# 1718 brightness 0.3
# 1719 brightness 1.4
# 1720 contrast 0.3
# 1721 contrast 1.4
# 1722 sharpness 5.0
# 1723 sharpness 20.0
# 1724 Color 0.0
# 1725 Color 10.0
# 1726 mirror origional
# ___________________ bewerken afbeelding 165 ___________________
# 1727 brightness 0.3
# 1728 brightness 1.4
# 1729 contrast 0.3
# 1730 contrast 1.4
# 1731 sharpness 5.0
# 1732 sharpness 20.0
# 1733 Color 0.0
# 1734 Color 10.0
# 1735 mirror origional
# ___________________ bewerken afbeelding 166 ___________________
# 1736 brightness 0.3
# 1737 brightness 1.4
# 1738 contrast 0.3
# 1739 contrast 1.4
# 1740 sharpness 5.0
# 1741 sharpness 20.0
# 1742 Color 0.0
# 1743 Color 10.0
# 1744 mirror origional
# ___________________ bewerken afbeelding 167 ___________________
# 1745 brightness 0.3
# 1746 brightness 1.4
# 1747 contrast 0.3
# 1748 contrast 1.4
# 1749 sharpness 5.0
# 1750 sharpness 20.0
# 1751 Color 0.0
# 1752 Color 10.0
# 1753 mirror origional
# ___________________ bewerken afbeelding 168 ___________________
# 1754 brightness 0.3
# 1755 brightness 1.4
# 1756 contrast 0.3
# 1757 contrast 1.4
# 1758 sharpness 5.0
# 1759 sharpness 20.0
# 1760 Color 0.0
# 1761 Color 10.0
# 1762 mirror origional
# ___________________ bewerken afbeelding 169 ___________________
# 1763 brightness 0.3
# 1764 brightness 1.4
# 1765 contrast 0.3
# 1766 contrast 1.4
# 1767 sharpness 5.0
# 1768 sharpness 20.0
# 1769 Color 0.0
# 1770 Color 10.0
# 1771 mirror origional
# ___________________ bewerken afbeelding 170 ___________________
# 1772 brightness 0.3
# 1773 brightness 1.4
# 1774 contrast 0.3
# 1775 contrast 1.4
# 1776 sharpness 5.0
# 1777 sharpness 20.0
# 1778 Color 0.0
# 1779 Color 10.0
# 1780 mirror origional
# ___________________ bewerken afbeelding 171 ___________________
# 1781 brightness 0.3
# 1782 brightness 1.4
# 1783 contrast 0.3
# 1784 contrast 1.4
# 1785 sharpness 5.0
# 1786 sharpness 20.0
# 1787 Color 0.0
# 1788 Color 10.0
# 1789 mirror origional
# ___________________ bewerken afbeelding 172 ___________________
# 1790 brightness 0.3
# 1791 brightness 1.4
# 1792 contrast 0.3
# 1793 contrast 1.4
# 1794 sharpness 5.0
# 1795 sharpness 20.0
# 1796 Color 0.0
# 1797 Color 10.0
# 1798 mirror origional
# ___________________ bewerken afbeelding 173 ___________________
# 1799 brightness 0.3
# 1800 brightness 1.4
# 1801 contrast 0.3
# 1802 contrast 1.4
# 1803 sharpness 5.0
# 1804 sharpness 20.0
# 1805 Color 0.0
# 1806 Color 10.0
# 1807 mirror origional
# ___________________ bewerken afbeelding 174 ___________________
# 1808 brightness 0.3
# 1809 brightness 1.4
# 1810 contrast 0.3
# 1811 contrast 1.4
# 1812 sharpness 5.0
# 1813 sharpness 20.0
# 1814 Color 0.0
# 1815 Color 10.0
# 1816 mirror origional
# ___________________ bewerken afbeelding 175 ___________________
# 1817 brightness 0.3
# 1818 brightness 1.4
# 1819 contrast 0.3
# 1820 contrast 1.4
# 1821 sharpness 5.0
# 1822 sharpness 20.0
# 1823 Color 0.0
# 1824 Color 10.0
# 1825 mirror origional
# ___________________ bewerken afbeelding 176 ___________________
# 1826 brightness 0.3
# 1827 brightness 1.4
# 1828 contrast 0.3
# 1829 contrast 1.4
# 1830 sharpness 5.0
# 1831 sharpness 20.0
# 1832 Color 0.0
# 1833 Color 10.0
# 1834 mirror origional
# ___________________ bewerken afbeelding 177 ___________________
# 1835 brightness 0.3
# 1836 brightness 1.4
# 1837 contrast 0.3
# 1838 contrast 1.4
# 1839 sharpness 5.0
# 1840 sharpness 20.0
# 1841 Color 0.0
# 1842 Color 10.0
# 1843 mirror origional
# ___________________ bewerken afbeelding 178 ___________________
# 1844 brightness 0.3
# 1845 brightness 1.4
# 1846 contrast 0.3
# 1847 contrast 1.4
# 1848 sharpness 5.0
# 1849 sharpness 20.0
# 1850 Color 0.0
# 1851 Color 10.0
# 1852 mirror origional
# ___________________ bewerken afbeelding 179 ___________________
# 1853 brightness 0.3
# 1854 brightness 1.4
# 1855 contrast 0.3
# 1856 contrast 1.4
# 1857 sharpness 5.0
# 1858 sharpness 20.0
# 1859 Color 0.0
# 1860 Color 10.0
# 1861 mirror origional
# ___________________ bewerken afbeelding 180 ___________________
# 1862 brightness 0.3
# 1863 brightness 1.4
# 1864 contrast 0.3
# 1865 contrast 1.4
# 1866 sharpness 5.0
# 1867 sharpness 20.0
# 1868 Color 0.0
# 1869 Color 10.0
# 1870 mirror origional
# ___________________ bewerken afbeelding 181 ___________________
# 1871 brightness 0.3
# 1872 brightness 1.4
# 1873 contrast 0.3
# 1874 contrast 1.4
# 1875 sharpness 5.0
# 1876 sharpness 20.0
# 1877 Color 0.0
# 1878 Color 10.0
# 1879 mirror origional
# ___________________ bewerken afbeelding 182 ___________________
# 1880 brightness 0.3
# 1881 brightness 1.4
# 1882 contrast 0.3
# 1883 contrast 1.4
# 1884 sharpness 5.0
# 1885 sharpness 20.0
# 1886 Color 0.0
# 1887 Color 10.0
# 1888 mirror origional
# ___________________ bewerken afbeelding 183 ___________________
# 1889 brightness 0.3
# 1890 brightness 1.4
# 1891 contrast 0.3
# 1892 contrast 1.4
# 1893 sharpness 5.0
# 1894 sharpness 20.0
# 1895 Color 0.0
# 1896 Color 10.0
# 1897 mirror origional
# ___________________ bewerken afbeelding 184 ___________________
# 1898 brightness 0.3
# 1899 brightness 1.4
# 1900 contrast 0.3
# 1901 contrast 1.4
# 1902 sharpness 5.0
# 1903 sharpness 20.0
# 1904 Color 0.0
# 1905 Color 10.0
# 1906 mirror origional
# ___________________ bewerken afbeelding 185 ___________________
# 1907 brightness 0.3
# 1908 brightness 1.4
# 1909 contrast 0.3
# 1910 contrast 1.4
# 1911 sharpness 5.0
# 1912 sharpness 20.0
# 1913 Color 0.0
# 1914 Color 10.0
# 1915 mirror origional
# ___________________ bewerken afbeelding 186 ___________________
# 1916 brightness 0.3
# 1917 brightness 1.4
# 1918 contrast 0.3
# 1919 contrast 1.4
# 1920 sharpness 5.0
# 1921 sharpness 20.0
# 1922 Color 0.0
# 1923 Color 10.0
# 1924 mirror origional
# ___________________ bewerken afbeelding 187 ___________________
# 1925 brightness 0.3
# 1926 brightness 1.4
# 1927 contrast 0.3
# 1928 contrast 1.4
# 1929 sharpness 5.0
# 1930 sharpness 20.0
# 1931 Color 0.0
# 1932 Color 10.0
# 1933 mirror origional
# ___________________ bewerken afbeelding 188 ___________________
# 1934 brightness 0.3
# 1935 brightness 1.4
# 1936 contrast 0.3
# 1937 contrast 1.4
# 1938 sharpness 5.0
# 1939 sharpness 20.0
# 1940 Color 0.0
# 1941 Color 10.0
# 1942 mirror origional
# ___________________ bewerken afbeelding 189 ___________________
# 1943 brightness 0.3
# 1944 brightness 1.4
# 1945 contrast 0.3
# 1946 contrast 1.4
# 1947 sharpness 5.0
# 1948 sharpness 20.0
# 1949 Color 0.0
# 1950 Color 10.0
# 1951 mirror origional
# ___________________ bewerken afbeelding 190 ___________________
# 1952 brightness 0.3
# 1953 brightness 1.4
# 1954 contrast 0.3
# 1955 contrast 1.4
# 1956 sharpness 5.0
# 1957 sharpness 20.0
# 1958 Color 0.0
# 1959 Color 10.0
# 1960 mirror origional
# ___________________ bewerken afbeelding 191 ___________________
# 1961 brightness 0.3
# 1962 brightness 1.4
# 1963 contrast 0.3
# 1964 contrast 1.4
# 1965 sharpness 5.0
# 1966 sharpness 20.0
# 1967 Color 0.0
# 1968 Color 10.0
# 1969 mirror origional
# ___________________ bewerken afbeelding 192 ___________________
# 1970 brightness 0.3
# 1971 brightness 1.4
# 1972 contrast 0.3
# 1973 contrast 1.4
# 1974 sharpness 5.0
# 1975 sharpness 20.0
# 1976 Color 0.0
# 1977 Color 10.0
# 1978 mirror origional
# ___________________ bewerken afbeelding 193 ___________________
# 1979 brightness 0.3
# 1980 brightness 1.4
# 1981 contrast 0.3
# 1982 contrast 1.4
# 1983 sharpness 5.0
# 1984 sharpness 20.0
# 1985 Color 0.0
# 1986 Color 10.0
# 1987 mirror origional
# ___________________ bewerken afbeelding 194 ___________________
# 1988 brightness 0.3
# 1989 brightness 1.4
# 1990 contrast 0.3
# 1991 contrast 1.4
# 1992 sharpness 5.0
# 1993 sharpness 20.0
# 1994 Color 0.0
# 1995 Color 10.0
# 1996 mirror origional
# ___________________ bewerken afbeelding 195 ___________________
# 1997 brightness 0.3
# 1998 brightness 1.4
# 1999 contrast 0.3
# 2000 contrast 1.4
# 2001 sharpness 5.0
# 2002 sharpness 20.0
# 2003 Color 0.0
# 2004 Color 10.0
# 2005 mirror origional
# ___________________ bewerken afbeelding 196 ___________________
# 2006 brightness 0.3
# 2007 brightness 1.4
# 2008 contrast 0.3
# 2009 contrast 1.4
# 2010 sharpness 5.0
# 2011 sharpness 20.0
# 2012 Color 0.0
# 2013 Color 10.0
# 2014 mirror origional
# ___________________ bewerken afbeelding 197 ___________________
# 2015 brightness 0.3
# 2016 brightness 1.4
# 2017 contrast 0.3
# 2018 contrast 1.4
# 2019 sharpness 5.0
# 2020 sharpness 20.0
# 2021 Color 0.0
# 2022 Color 10.0
# 2023 mirror origional
# ___________________ bewerken afbeelding 198 ___________________
# 2024 brightness 0.3
# 2025 brightness 1.4
# 2026 contrast 0.3
# 2027 contrast 1.4
# 2028 sharpness 5.0
# 2029 sharpness 20.0
# 2030 Color 0.0
# 2031 Color 10.0
# 2032 mirror origional
# ___________________ bewerken afbeelding 199 ___________________
# 2033 brightness 0.3
# 2034 brightness 1.4
# 2035 contrast 0.3
# 2036 contrast 1.4
# 2037 sharpness 5.0
# 2038 sharpness 20.0
# 2039 Color 0.0
# 2040 Color 10.0
# 2041 mirror origional
# ___________________ bewerken afbeelding 200 ___________________
# 2042 brightness 0.3
# 2043 brightness 1.4
# 2044 contrast 0.3
# 2045 contrast 1.4
# 2046 sharpness 5.0
# 2047 sharpness 20.0
# 2048 Color 0.0
# 2049 Color 10.0
# 2050 mirror origional
# ___________________ bewerken afbeelding 201 ___________________
# 2051 brightness 0.3
# 2052 brightness 1.4
# 2053 contrast 0.3
# 2054 contrast 1.4
# 2055 sharpness 5.0
# 2056 sharpness 20.0
# 2057 Color 0.0
# 2058 Color 10.0
# 2059 mirror origional
# ___________________ bewerken afbeelding 202 ___________________
# 2060 brightness 0.3
# 2061 brightness 1.4
# 2062 contrast 0.3
# 2063 contrast 1.4
# 2064 sharpness 5.0
# 2065 sharpness 20.0
# 2066 Color 0.0
# 2067 Color 10.0
# 2068 mirror origional
# ___________________ bewerken afbeelding 203 ___________________
# 2069 brightness 0.3
# 2070 brightness 1.4
# 2071 contrast 0.3
# 2072 contrast 1.4
# 2073 sharpness 5.0
# 2074 sharpness 20.0
# 2075 Color 0.0
# 2076 Color 10.0
# 2077 mirror origional
# ___________________ bewerken afbeelding 204 ___________________
# 2078 brightness 0.3
# 2079 brightness 1.4
# 2080 contrast 0.3
# 2081 contrast 1.4
# 2082 sharpness 5.0
# 2083 sharpness 20.0
# 2084 Color 0.0
# 2085 Color 10.0
# 2086 mirror origional
# ___________________ bewerken afbeelding 205 ___________________
# 2087 brightness 0.3
# 2088 brightness 1.4
# 2089 contrast 0.3
# 2090 contrast 1.4
# 2091 sharpness 5.0
# 2092 sharpness 20.0
# 2093 Color 0.0
# 2094 Color 10.0
# 2095 mirror origional
# ___________________ bewerken afbeelding 206 ___________________
# 2096 brightness 0.3
# 2097 brightness 1.4
# 2098 contrast 0.3
# 2099 contrast 1.4
# 2100 sharpness 5.0
# 2101 sharpness 20.0
# 2102 Color 0.0
# 2103 Color 10.0
# 2104 mirror origional
# ___________________ bewerken afbeelding 207 ___________________
# 2105 brightness 0.3
# 2106 brightness 1.4
# 2107 contrast 0.3
# 2108 contrast 1.4
# 2109 sharpness 5.0
# 2110 sharpness 20.0
# 2111 Color 0.0
# 2112 Color 10.0
# 2113 mirror origional
# ___________________ bewerken afbeelding 208 ___________________
# 2114 brightness 0.3
# 2115 brightness 1.4
# 2116 contrast 0.3
# 2117 contrast 1.4
# 2118 sharpness 5.0
# 2119 sharpness 20.0
# 2120 Color 0.0
# 2121 Color 10.0
# 2122 mirror origional
# ___________________ bewerken afbeelding 209 ___________________
# 2123 brightness 0.3
# 2124 brightness 1.4
# 2125 contrast 0.3
# 2126 contrast 1.4
# 2127 sharpness 5.0
# 2128 sharpness 20.0
# 2129 Color 0.0
# 2130 Color 10.0
# 2131 mirror origional
# ___________________ bewerken afbeelding 210 ___________________
# 2132 brightness 0.3
# 2133 brightness 1.4
# 2134 contrast 0.3
# 2135 contrast 1.4
# 2136 sharpness 5.0
# 2137 sharpness 20.0
# 2138 Color 0.0
# 2139 Color 10.0
# 2140 mirror origional
# ___________________ bewerken afbeelding 211 ___________________
# 2141 brightness 0.3
# 2142 brightness 1.4
# 2143 contrast 0.3
# 2144 contrast 1.4
# 2145 sharpness 5.0
# 2146 sharpness 20.0
# 2147 Color 0.0
# 2148 Color 10.0
# 2149 mirror origional
# ___________________ bewerken afbeelding 212 ___________________
# 2150 brightness 0.3
# 2151 brightness 1.4
# 2152 contrast 0.3
# 2153 contrast 1.4
# 2154 sharpness 5.0
# 2155 sharpness 20.0
# 2156 Color 0.0
# 2157 Color 10.0
# 2158 mirror origional
# ___________________ bewerken afbeelding 213 ___________________
# 2159 brightness 0.3
# 2160 brightness 1.4
# 2161 contrast 0.3
# 2162 contrast 1.4
# 2163 sharpness 5.0
# 2164 sharpness 20.0
# 2165 Color 0.0
# 2166 Color 10.0
# 2167 mirror origional
# ___________________ bewerken afbeelding 214 ___________________
# 2168 brightness 0.3
# 2169 brightness 1.4
# 2170 contrast 0.3
# 2171 contrast 1.4
# 2172 sharpness 5.0
# 2173 sharpness 20.0
# 2174 Color 0.0
# 2175 Color 10.0
# 2176 mirror origional
# ___________________ bewerken afbeelding 215 ___________________
# 2177 brightness 0.3
# 2178 brightness 1.4
# 2179 contrast 0.3
# 2180 contrast 1.4
# 2181 sharpness 5.0
# 2182 sharpness 20.0
# 2183 Color 0.0
# 2184 Color 10.0
# 2185 mirror origional
# ___________________ bewerken afbeelding 216 ___________________
# 2186 brightness 0.3
# 2187 brightness 1.4
# 2188 contrast 0.3
# 2189 contrast 1.4
# 2190 sharpness 5.0
# 2191 sharpness 20.0
# 2192 Color 0.0
# 2193 Color 10.0
# 2194 mirror origional
# ___________________ bewerken afbeelding 217 ___________________
# 2195 brightness 0.3
# 2196 brightness 1.4
# 2197 contrast 0.3
# 2198 contrast 1.4
# 2199 sharpness 5.0
# 2200 sharpness 20.0
# 2201 Color 0.0
# 2202 Color 10.0
# 2203 mirror origional
# ___________________ bewerken afbeelding 218 ___________________
# 2204 brightness 0.3
# 2205 brightness 1.4
# 2206 contrast 0.3
# 2207 contrast 1.4
# 2208 sharpness 5.0
# 2209 sharpness 20.0
# 2210 Color 0.0
# 2211 Color 10.0
# 2212 mirror origional
# ___________________ bewerken afbeelding 219 ___________________
# 2213 brightness 0.3
# 2214 brightness 1.4
# 2215 contrast 0.3
# 2216 contrast 1.4
# 2217 sharpness 5.0
# 2218 sharpness 20.0
# 2219 Color 0.0
# 2220 Color 10.0
# 2221 mirror origional
# ___________________ bewerken afbeelding 220 ___________________
# 2222 brightness 0.3
# 2223 brightness 1.4
# 2224 contrast 0.3
# 2225 contrast 1.4
# 2226 sharpness 5.0
# 2227 sharpness 20.0
# 2228 Color 0.0
# 2229 Color 10.0
# 2230 mirror origional
# ___________________ bewerken afbeelding 221 ___________________
# 2231 brightness 0.3
# 2232 brightness 1.4
# 2233 contrast 0.3
# 2234 contrast 1.4
# 2235 sharpness 5.0
# 2236 sharpness 20.0
# 2237 Color 0.0
# 2238 Color 10.0
# 2239 mirror origional
# ___________________ bewerken afbeelding 222 ___________________
# 2240 brightness 0.3
# 2241 brightness 1.4
# 2242 contrast 0.3
# 2243 contrast 1.4
# 2244 sharpness 5.0
# 2245 sharpness 20.0
# 2246 Color 0.0
# 2247 Color 10.0
# 2248 mirror origional
# ___________________ bewerken afbeelding 223 ___________________
# 2249 brightness 0.3
# 2250 brightness 1.4
# 2251 contrast 0.3
# 2252 contrast 1.4
# 2253 sharpness 5.0
# 2254 sharpness 20.0
# 2255 Color 0.0
# 2256 Color 10.0
# 2257 mirror origional
# ___________________ bewerken afbeelding 224 ___________________
# 2258 brightness 0.3
# 2259 brightness 1.4
# 2260 contrast 0.3
# 2261 contrast 1.4
# 2262 sharpness 5.0
# 2263 sharpness 20.0
# 2264 Color 0.0
# 2265 Color 10.0
# 2266 mirror origional
# ___________________ bewerken afbeelding 225 ___________________
# 2267 brightness 0.3
# 2268 brightness 1.4
# 2269 contrast 0.3
# 2270 contrast 1.4
# 2271 sharpness 5.0
# 2272 sharpness 20.0
# 2273 Color 0.0
# 2274 Color 10.0
# 2275 mirror origional
# ___________________ bewerken afbeelding 226 ___________________
# 2276 brightness 0.3
# 2277 brightness 1.4
# 2278 contrast 0.3
# 2279 contrast 1.4
# 2280 sharpness 5.0
# 2281 sharpness 20.0
# 2282 Color 0.0
# 2283 Color 10.0
# 2284 mirror origional
# ___________________ bewerken afbeelding 227 ___________________
# 2285 brightness 0.3
# 2286 brightness 1.4
# 2287 contrast 0.3
# 2288 contrast 1.4
# 2289 sharpness 5.0
# 2290 sharpness 20.0
# 2291 Color 0.0
# 2292 Color 10.0
# 2293 mirror origional
# ___________________ bewerken afbeelding 228 ___________________
# 2294 brightness 0.3
# 2295 brightness 1.4
# 2296 contrast 0.3
# 2297 contrast 1.4
# 2298 sharpness 5.0
# 2299 sharpness 20.0
# 2300 Color 0.0
# 2301 Color 10.0
# 2302 mirror origional
# ___________________ bewerken afbeelding 229 ___________________
# 2303 brightness 0.3
# 2304 brightness 1.4
# 2305 contrast 0.3
# 2306 contrast 1.4
# 2307 sharpness 5.0
# 2308 sharpness 20.0
# 2309 Color 0.0
# 2310 Color 10.0
# 2311 mirror origional
# ___________________ bewerken afbeelding 230 ___________________
# 2312 brightness 0.3
# 2313 brightness 1.4
# 2314 contrast 0.3
# 2315 contrast 1.4
# 2316 sharpness 5.0
# 2317 sharpness 20.0
# 2318 Color 0.0
# 2319 Color 10.0
# 2320 mirror origional
# ___________________ bewerken afbeelding 231 ___________________
# 2321 brightness 0.3
# 2322 brightness 1.4
# 2323 contrast 0.3
# 2324 contrast 1.4
# 2325 sharpness 5.0
# 2326 sharpness 20.0
# 2327 Color 0.0
# 2328 Color 10.0
# 2329 mirror origional
# ___________________ bewerken afbeelding 232 ___________________
# 2330 brightness 0.3
# 2331 brightness 1.4
# 2332 contrast 0.3
# 2333 contrast 1.4
# 2334 sharpness 5.0
# 2335 sharpness 20.0
# 2336 Color 0.0
# 2337 Color 10.0
# 2338 mirror origional
# ___________________ bewerken afbeelding 233 ___________________
# 2339 brightness 0.3
# 2340 brightness 1.4
# 2341 contrast 0.3
# 2342 contrast 1.4
# 2343 sharpness 5.0
# 2344 sharpness 20.0
# 2345 Color 0.0
# 2346 Color 10.0
# 2347 mirror origional
# ___________________ bewerken afbeelding 234 ___________________
# 2348 brightness 0.3
# 2349 brightness 1.4
# 2350 contrast 0.3
# 2351 contrast 1.4
# 2352 sharpness 5.0
# 2353 sharpness 20.0
# 2354 Color 0.0
# 2355 Color 10.0
# 2356 mirror origional
# ___________________ bewerken afbeelding 235 ___________________
# 2357 brightness 0.3
# 2358 brightness 1.4
# 2359 contrast 0.3
# 2360 contrast 1.4
# 2361 sharpness 5.0
# 2362 sharpness 20.0
# 2363 Color 0.0
# 2364 Color 10.0
# 2365 mirror origional
# ___________________ bewerken afbeelding 236 ___________________
# 2366 brightness 0.3
# 2367 brightness 1.4
# 2368 contrast 0.3
# 2369 contrast 1.4
# 2370 sharpness 5.0
# 2371 sharpness 20.0
# 2372 Color 0.0
# 2373 Color 10.0
# 2374 mirror origional
# ___________________ bewerken afbeelding 237 ___________________
# 2375 brightness 0.3
# 2376 brightness 1.4
# 2377 contrast 0.3
# 2378 contrast 1.4
# 2379 sharpness 5.0
# 2380 sharpness 20.0
# 2381 Color 0.0
# 2382 Color 10.0
# 2383 mirror origional
# ___________________ bewerken afbeelding 238 ___________________
# 2384 brightness 0.3
# 2385 brightness 1.4
# 2386 contrast 0.3
# 2387 contrast 1.4
# 2388 sharpness 5.0
# 2389 sharpness 20.0
# 2390 Color 0.0
# 2391 Color 10.0
# 2392 mirror origional
# ___________________ bewerken afbeelding 239 ___________________
# 2393 brightness 0.3
# 2394 brightness 1.4
# 2395 contrast 0.3
# 2396 contrast 1.4
# 2397 sharpness 5.0
# 2398 sharpness 20.0
# 2399 Color 0.0
# 2400 Color 10.0
# 2401 mirror origional
# ___________________ bewerken afbeelding 240 ___________________
# 2402 brightness 0.3
# 2403 brightness 1.4
# 2404 contrast 0.3
# 2405 contrast 1.4
# 2406 sharpness 5.0
# 2407 sharpness 20.0
# 2408 Color 0.0
# 2409 Color 10.0
# 2410 mirror origional
# ___________________ bewerken afbeelding 241 ___________________
# 2411 brightness 0.3
# 2412 brightness 1.4
# 2413 contrast 0.3
# 2414 contrast 1.4
# 2415 sharpness 5.0
# 2416 sharpness 20.0
# 2417 Color 0.0
# 2418 Color 10.0
# 2419 mirror origional
# ___________________ bewerken afbeelding 242 ___________________
# 2420 brightness 0.3
# 2421 brightness 1.4
# 2422 contrast 0.3
# 2423 contrast 1.4
# 2424 sharpness 5.0
# 2425 sharpness 20.0
# 2426 Color 0.0
# 2427 Color 10.0
# 2428 mirror origional
# ___________________ bewerken afbeelding 243 ___________________
# 2429 brightness 0.3
# 2430 brightness 1.4
# 2431 contrast 0.3
# 2432 contrast 1.4
# 2433 sharpness 5.0
# 2434 sharpness 20.0
# 2435 Color 0.0
# 2436 Color 10.0
# 2437 mirror origional
# ___________________ bewerken afbeelding 244 ___________________
# 2438 brightness 0.3
# 2439 brightness 1.4
# 2440 contrast 0.3
# 2441 contrast 1.4
# 2442 sharpness 5.0
# 2443 sharpness 20.0
# 2444 Color 0.0
# 2445 Color 10.0
# 2446 mirror origional
# ___________________ bewerken afbeelding 245 ___________________
# 2447 brightness 0.3
# 2448 brightness 1.4
# 2449 contrast 0.3
# 2450 contrast 1.4
# 2451 sharpness 5.0
# 2452 sharpness 20.0
# 2453 Color 0.0
# 2454 Color 10.0
# 2455 mirror origional
# ___________________ bewerken afbeelding 246 ___________________
# 2456 brightness 0.3
# 2457 brightness 1.4
# 2458 contrast 0.3
# 2459 contrast 1.4
# 2460 sharpness 5.0
# 2461 sharpness 20.0
# 2462 Color 0.0
# 2463 Color 10.0
# 2464 mirror origional
# ___________________ bewerken afbeelding 247 ___________________
# 2465 brightness 0.3
# 2466 brightness 1.4
# 2467 contrast 0.3
# 2468 contrast 1.4
# 2469 sharpness 5.0
# 2470 sharpness 20.0
# 2471 Color 0.0
# 2472 Color 10.0
# 2473 mirror origional
# ___________________ bewerken afbeelding 248 ___________________
# 2474 brightness 0.3
# 2475 brightness 1.4
# 2476 contrast 0.3
# 2477 contrast 1.4
# 2478 sharpness 5.0
# 2479 sharpness 20.0
# 2480 Color 0.0
# 2481 Color 10.0
# 2482 mirror origional
# ___________________ bewerken afbeelding 249 ___________________
# 2483 brightness 0.3
# 2484 brightness 1.4
# 2485 contrast 0.3
# 2486 contrast 1.4
# 2487 sharpness 5.0
# 2488 sharpness 20.0
# 2489 Color 0.0
# 2490 Color 10.0
# 2491 mirror origional
# ___________________ bewerken afbeelding 250 ___________________
# 2492 brightness 0.3
# 2493 brightness 1.4
# 2494 contrast 0.3
# 2495 contrast 1.4
# 2496 sharpness 5.0
# 2497 sharpness 20.0
# 2498 Color 0.0
# 2499 Color 10.0
# 2500 mirror origional

# %% [markdown]
# ## Controle

# %%
import matplotlib.pyplot as plt
import random


#randomly select frame number
select_frame_number = random.randint(251,2500)
#manually select frame number:
#select_frame_number = 1000

img_frame = '/datc/shipping/processed_pictures_m/frames/frame_'+ str(select_frame_number)+'.jpg'
img_overlay = '/datc/shipping/processed_pictures_m/overlays/frame_' + str(select_frame_number) + '_mask.gif'

read_img_frame = plt.imread(img_frame)
read_img_overlay = plt.imread(img_overlay)

plt.subplot(2,1,1)
plt.imshow(read_img_frame)
plt.title('frame')
plt.axis('off')

plt.subplot(2,1,2)
plt.imshow(read_img_overlay)
plt.title('overlay')
plt.axis('off')

plt.show()
